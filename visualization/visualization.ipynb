# %%
import pandas as pd
import numpy as np
import altair as alt

# %% [markdown]
# # GDP growth data from World Bank
# # https://data.worldbank.org/indicator/NY.GDP.MKTP.KD.ZG?view=chart

# %%
# GDP growth (annual %)

# %%
# note the first 4 lines of the csv aren't part of the data, so skip them
gdp_growth_df = pd.read_csv("API_NY.GDP.MKTP.KD.ZG_DS2_en_csv_v2_122369.csv", skiprows=4)

# %%
gdp_growth_df
# Out:
#                     Country Name Country Code         Indicator Name  \
# 0                          Aruba          ABW  GDP growth (annual %)
# 1    Africa Eastern and Southern          AFE  GDP growth (annual %)
# 2                    Afghanistan          AFG  GDP growth (annual %)
# 3     Africa Western and Central          AFW  GDP growth (annual %)
# 4                         Angola          AGO  GDP growth (annual %)
# ..                           ...          ...                    ...
# 261                       Kosovo          XKX  GDP growth (annual %)
# 262                  Yemen, Rep.          YEM  GDP growth (annual %)
# 263                 South Africa          ZAF  GDP growth (annual %)
# 264                       Zambia          ZMB  GDP growth (annual %)
# 265                     Zimbabwe          ZWE  GDP growth (annual %)
#
#         Indicator Code  1960      1961      1962      1963       1964  \
# ...

# %%
# get top growing countries in 2024

# %%
gdp_growth_df_top_2024 = gdp_growth_df.sort_values(by='2024', ascending=False)

# %%
gdp_growth_df_top_2024
# Out:
#                Country Name Country Code         Indicator Name  \
# 94                   Guyana          GUY  GDP growth (annual %)
# 49   Caribbean small states          CSS  GDP growth (annual %)
# 82                  Georgia          GEO  GDP growth (annual %)
# 260                   Samoa          WSM  GDP growth (annual %)
# 122         Kyrgyz Republic          KGZ  GDP growth (annual %)
# ..                      ...          ...                    ...
# 245                  Tuvalu          TUV  GDP growth (annual %)
# 254           Venezuela, RB          VEN  GDP growth (annual %)
# 255  British Virgin Islands          VGB  GDP growth (annual %)
# 256   Virgin Islands (U.S.)          VIR  GDP growth (annual %)
# 262             Yemen, Rep.          YEM  GDP growth (annual %)
#
#         Indicator Code  1960      1961      1962       1963       1964  \
# 94   NY.GDP.MKTP.KD.ZG   NaN  4.689524  1.104926 -12.278657  11.360282
# ...

# %%
# gdp_growth_df_top_2024

# %%
# pd.melt(gdp_growth_df_top_2024, id_vars='Country Name')

# %% [markdown]
# # Notes for pd.melt()
# # id_vars = 'identifier variables'. These are columns you want to keep as-is (not melt)
# ## variable column is former column names
# ## value column is cell values

# %%
# data goes from 1960 to 2024. Make a list of those numbers
years_of_data = list(range(1960, 2025))

# convert the list into strings so I can iterate over column names
years_of_data_str = [str(x) for x in years_of_data]

# %%
columns_to_keep = ['Country Name'] + years_of_data_str

# %%
# just keep the columns of country name and years
gdp_growth_df_top_2024 = gdp_growth_df_top_2024[columns_to_keep]

# %%
gdp_growth_df_top_2024
# Out:
#                Country Name  1960      1961      1962       1963       1964  \
# 94                   Guyana   NaN  4.689524  1.104926 -12.278657  11.360282
# 49   Caribbean small states   NaN  9.704357  5.307244   2.292332   8.154308
# 82                  Georgia   NaN  4.865941  5.113016   4.201879   5.429588
# 260                   Samoa   NaN       NaN       NaN        NaN        NaN
# 122         Kyrgyz Republic   NaN       NaN       NaN        NaN        NaN
# ..                      ...   ...       ...       ...        ...        ...
# 245                  Tuvalu   NaN       NaN       NaN        NaN        NaN
# 254           Venezuela, RB   NaN  3.192519  8.532934   3.900951  11.129345
# 255  British Virgin Islands   NaN       NaN       NaN        NaN        NaN
# 256   Virgin Islands (U.S.)   NaN       NaN       NaN        NaN        NaN
# 262             Yemen, Rep.   NaN       NaN       NaN        NaN        NaN
#
# ...

# %%
top_10_gdp_growth_countries_2024_df = gdp_growth_df_top_2024.iloc[0:10]

# %%
# Melt the data to make it easier to visualize

# %%
# have identifier column be Country Name, get the variable column (other column names), and their corresponding
# values in value
# pd.melt(top_10_gdp_growth_countries_2024_df, id_vars='Country Name')
# Out:
#                Country Name variable     value
# 0                    Guyana     1960       NaN
# 1    Caribbean small states     1960       NaN
# 2                   Georgia     1960       NaN
# 3                     Samoa     1960       NaN
# 4           Kyrgyz Republic     1960       NaN
# ..                      ...      ...       ...
# 645                  Rwanda     2024  8.890655
# 646        Macao SAR, China     2024  8.808160
# 647                   Niger     2024  8.421598
# 648              Tajikistan     2024  8.400000
# 649                  Belize     2024  8.151790
#
# [650 rows x 3 columns]

# %% [markdown]
# # above makes sense. Because there are 65 years (65 rows) and 10 countries

# %%
# top top_10_gdp_growth_countries_2024_df

# %%
top_10_countries_combined_df_melted = pd.melt(top_10_gdp_growth_countries_2024_df, id_vars='Country Name')

# %%
top_10_countries_combined_df_melted
# Out:
#                Country Name variable     value
# 0                    Guyana     1960       NaN
# 1    Caribbean small states     1960       NaN
# 2                   Georgia     1960       NaN
# 3                     Samoa     1960       NaN
# 4           Kyrgyz Republic     1960       NaN
# ..                      ...      ...       ...
# 645                  Rwanda     2024  8.890655
# 646        Macao SAR, China     2024  8.808160
# 647                   Niger     2024  8.421598
# 648              Tajikistan     2024  8.400000
# 649                  Belize     2024  8.151790
#
# [650 rows x 3 columns]

# %%
alt.Chart(top_10_countries_combined_df_melted).mark_line().encode(
  #x=alt.X('year'),
  x=alt.X('variable'),
  #y=alt.Y('gdp_growth_rate'),
  y=alt.Y('value'),
  color = alt.Color('Country Name')
).properties(
    width=900,
    height=500
)
# Out:
# alt.Chart(...)

# %% [markdown]
# # top 10 fastest growing economies in 2024

# %%
gdp_growth_df_top_2024.iloc[0:10][['Country Name', '2024']]
# Out:
#                Country Name       2024
# 94                   Guyana  43.372009
# 49   Caribbean small states  13.344326
# 82                  Georgia   9.428572
# 260                   Samoa   9.422350
# 122         Kyrgyz Republic   9.040136
# 203                  Rwanda   8.890655
# 146        Macao SAR, China   8.808160
# 173                   Niger   8.421598
# 234              Tajikistan   8.400000
# 26                   Belize   8.151790

# %%
top_10_country_names = gdp_growth_df_top_2024.iloc[0:10]['Country Name'].values

# %%
top_10_gdp_growth_countries_2024_df = gdp_growth_df_top_2024.iloc[0:10]

# %%
top_10_gdp_growth_countries_2024_df
# Out:
#                Country Name  1960      1961       1962       1963       1964  \
# 94                   Guyana   NaN  4.689524   1.104926 -12.278657  11.360282
# 49   Caribbean small states   NaN  9.704357   5.307244   2.292332   8.154308
# 82                  Georgia   NaN  4.865941   5.113016   4.201879   5.429588
# 260                   Samoa   NaN       NaN        NaN        NaN        NaN
# 122         Kyrgyz Republic   NaN       NaN        NaN        NaN        NaN
# 203                  Rwanda   NaN -4.297526  11.333798  -9.820444 -12.464993
# 146        Macao SAR, China   NaN       NaN        NaN        NaN        NaN
# 173                   Niger   NaN  4.546393  10.278713   9.428229   0.131040
# 234              Tajikistan   NaN       NaN        NaN        NaN        NaN
# 26                   Belize   NaN  4.892277   4.892652   4.956434   4.999880
#
#           1965      1966      1967      1968  ...       2015      2016  \
# ...

# %%
top_5_gdp_growth_countries_2024_df = gdp_growth_df_top_2024.iloc[0:5]

# %%
top_5_gdp_growth_countries_2024_df
# Out:
#                Country Name  1960      1961      1962       1963       1964  \
# 94                   Guyana   NaN  4.689524  1.104926 -12.278657  11.360282
# 49   Caribbean small states   NaN  9.704357  5.307244   2.292332   8.154308
# 82                  Georgia   NaN  4.865941  5.113016   4.201879   5.429588
# 260                   Samoa   NaN       NaN       NaN        NaN        NaN
# 122         Kyrgyz Republic   NaN       NaN       NaN        NaN        NaN
#
#           1965      1966      1967      1968  ...      2015      2016  \
# 94   10.541019  5.233274  4.313622  1.024828  ...  0.687405  3.807456
# 49    7.016108  6.939735  6.603136  6.148545  ... -0.130959 -3.025265
# 82   10.558637  7.535663  6.253082  4.455583  ...  3.351024  3.450215
# 260        NaN       NaN       NaN       NaN  ...  3.850362  7.983863
# 122        NaN       NaN       NaN       NaN  ...  3.875825  4.335856
#
#          2017      2018      2019       2020       2021       2022       2023  \
# ...

# %%
top_10_country_names
# Out:
# array(['Guyana', 'Caribbean small states', 'Georgia', 'Samoa',
#        'Kyrgyz Republic', 'Rwanda', 'Macao SAR, China', 'Niger',
#        'Tajikistan', 'Belize'], dtype=object)

# %%
# top_10_country_names.values

# %%
# top 20 fastest growing economies in 2024

# %%
gdp_growth_df_top_2024.iloc[0:20][['Country Name', '2024']]
# Out:
#                 Country Name       2024
# 94                    Guyana  43.372009
# 49    Caribbean small states  13.344326
# 82                   Georgia   9.428572
# 260                    Samoa   9.422350
# 122          Kyrgyz Republic   9.040136
# 203                   Rwanda   8.890655
# 146         Macao SAR, China   8.808160
# 173                    Niger   8.421598
# 234               Tajikistan   8.400000
# 26                    Belize   8.151790
# 18                     Benin   7.453116
# 72                  Ethiopia   7.316691
# 47                Cabo Verde   7.271881
# 257                 Viet Nam   7.091187
# 207                  Senegal   6.892007
# 43          Congo, Dem. Rep.   6.675930
# 252               Uzbekistan   6.500000
# 109                    India   6.484224
# 204               South Asia   6.224842
# 240  South Asia (IDA & IBRD)   6.224842

# %%
# x will be the year
# y will be the growth percentage
# label of country name

# 1960 to 2024

# %%
gdp_growth_df_top_2024
# Out:
#                Country Name  1960      1961      1962       1963       1964  \
# 94                   Guyana   NaN  4.689524  1.104926 -12.278657  11.360282
# 49   Caribbean small states   NaN  9.704357  5.307244   2.292332   8.154308
# 82                  Georgia   NaN  4.865941  5.113016   4.201879   5.429588
# 260                   Samoa   NaN       NaN       NaN        NaN        NaN
# 122         Kyrgyz Republic   NaN       NaN       NaN        NaN        NaN
# ..                      ...   ...       ...       ...        ...        ...
# 245                  Tuvalu   NaN       NaN       NaN        NaN        NaN
# 254           Venezuela, RB   NaN  3.192519  8.532934   3.900951  11.129345
# 255  British Virgin Islands   NaN       NaN       NaN        NaN        NaN
# 256   Virgin Islands (U.S.)   NaN       NaN       NaN        NaN        NaN
# 262             Yemen, Rep.   NaN       NaN       NaN        NaN        NaN
#
# ...

# %%
# iterate over the rows, make a df of them and later compbine?

# %%
temp_df = gdp_growth_df_top_2024.iloc[0]

# %%
# temp_df

# %%
# datagoes from 1960 to 2024. Make a list of those numbers
years_of_data = list(range(1960, 2025))

# %%
# years_of_data

# %%
# convert the list into strings so I can iterate over column names
years_of_data_str = [str(x) for x in years_of_data]

# %%
# years_of_data_str

# %%
column_names = gdp_growth_df_top_2024.columns

# %%
# USE TOP 5 or top 10

# %%
column_names = gdp_growth_df_top_2024.columns

dataframes_list = []

# for index, row in gdp_growth_df_top_2024.iloc[0:1].iterrows():
# top_10_gdp_growth_countries_2024_df
# for index, row in gdp_growth_df_top_2024.iterrows():
# for index, row in top_10_gdp_growth_countries_2024_df.iterrows():
for index, row in top_5_gdp_growth_countries_2024_df.iterrows():

    cur_country_name = row['Country Name']

    country_list = []
    year_list = []
    cur_gdp_growth_rate_list = []

    for year in years_of_data_str:
        # add country and year
        country_list.append(cur_country_name)
        year_list.append(year)
        cur_gdp_growth_rate_list.append(row[year])

    # make dataframe of current row to later combine into a larger dataframe
    cur_data_dict = {
        'country': country_list,
        'year': year_list,
        'gdp_growth_rate': cur_gdp_growth_rate_list
    }
    cur_df = pd.DataFrame(data=cur_data_dict)
    
    dataframes_list.append(cur_df)

# %%
top_5_countries_combined_df = pd.concat(dataframes_list)

# %%
top_5_countries_combined_df
# Out:
#             country  year  gdp_growth_rate
# 0            Guyana  1960              NaN
# 1            Guyana  1961         4.689524
# 2            Guyana  1962         1.104926
# 3            Guyana  1963       -12.278657
# 4            Guyana  1964        11.360282
# ..              ...   ...              ...
# 60  Kyrgyz Republic  2020        -7.148978
# 61  Kyrgyz Republic  2021         5.507008
# 62  Kyrgyz Republic  2022         8.967505
# 63  Kyrgyz Republic  2023         9.013293
# 64  Kyrgyz Republic  2024         9.040136
#
# [325 rows x 3 columns]

# %%
column_names = gdp_growth_df_top_2024.columns

dataframes_list = []

# for index, row in gdp_growth_df_top_2024.iloc[0:1].iterrows():
# top_10_gdp_growth_countries_2024_df
# for index, row in gdp_growth_df_top_2024.iterrows():
for index, row in top_10_gdp_growth_countries_2024_df.iterrows():
# for index, row in top_5_gdp_growth_countries_2024_df.iterrows():

    cur_country_name = row['Country Name']

    country_list = []
    year_list = []
    cur_gdp_growth_rate_list = []

    for year in years_of_data_str:
        # add country and year
        country_list.append(cur_country_name)
        year_list.append(year)
        cur_gdp_growth_rate_list.append(row[year])

    # make dataframe of current row to later combine into a larger dataframe
    cur_data_dict = {
        'country': country_list,
        'year': year_list,
        'gdp_growth_rate': cur_gdp_growth_rate_list
    }
    cur_df = pd.DataFrame(data=cur_data_dict)
    
    dataframes_list.append(cur_df)

# %%
top_10_countries_combined_df = pd.concat(dataframes_list)

# %%
top_10_countries_combined_df
# Out:
#    country  year  gdp_growth_rate
# 0   Guyana  1960              NaN
# 1   Guyana  1961         4.689524
# 2   Guyana  1962         1.104926
# 3   Guyana  1963       -12.278657
# 4   Guyana  1964        11.360282
# ..     ...   ...              ...
# 60  Belize  2020       -13.902910
# 61  Belize  2021        17.746170
# 62  Belize  2022         9.652978
# 63  Belize  2023         1.149017
# 64  Belize  2024         8.151790
#
# [650 rows x 3 columns]

# %% [markdown]
# # Top 5 countries visualized

# %%
alt.Chart(top_5_countries_combined_df).mark_line().encode(
  x=alt.X('year'),
  y=alt.Y('gdp_growth_rate'),
  color = alt.Color('country')
).properties(
    width=900,
    height=500
)
# Out:
# alt.Chart(...)

# %% [markdown]
# # Top 10 countries visualized

# %%
alt.Chart(top_10_countries_combined_df).mark_line().encode(
  x=alt.X('year'),
  y=alt.Y('gdp_growth_rate'),
  color = alt.Color('country')
).properties(
    width=900,
    height=500
)
# Out:
# alt.Chart(...)
